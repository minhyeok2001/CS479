# %% [markdown]
# <a href="https://colab.research.google.com/github/minhyeok2001/CS479/blob/main/CS479-Assignment-PointNet/PointNet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/minhyeok2001/CS479
# Out:
# Cloning into 'CS479'...
# remote: Enumerating objects: 157, done.
# remote: Counting objects: 100% (157/157), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 157 (delta 21), reused 155 (delta 19), pack-reused 0 (from 0)
# Receiving objects: 100% (157/157), 17.67 MiB | 46.15 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
# !pip install tqdm h5py matplotlib

# %%
# 기본 의존성 (PyTorch 포함)
# !pip install torch torchvision torchaudio -U

# fvcore, iopath
# !pip install "git+https://github.com/facebookresearch/fvcore" \
             "git+https://github.com/facebookresearch/iopath"

# pytorch3d (PyTorch 버전에 맞는 빌드 설치)
# !pip install "git+https://github.com/facebookresearch/pytorch3d.git"
# Out:
# ...
#   Cloning https://github.com/facebookresearch/fvcore to /tmp/pip-req-build-a34j4omn
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/fvcore /tmp/pip-req-build-a34j4omn
#   Resolved https://github.com/facebookresearch/fvcore to commit 70e69fb3ff7a82631f6a82061a7650c4f11da876
#   Preparing metadata (setup.py) ... done
# ...
#   Cloning https://github.com/facebookresearch/iopath to /tmp/pip-req-build-9r1_0rol
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/iopath /tmp/pip-req-build-9r1_0rol
#   Resolved https://github.com/facebookresearch/iopath to commit 7b222279acd73e86137c7b99a38a1299514f0204
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fvcore: filename=fvcore-0.1.6-py3-none-any.whl size=65635 sha256=15f4879788cdecaba101855124a8c8057c1fdd786b8a95d901dfd1a419a8ed47
# ...

# %%
cd CS479/CS479-Assignment-PointNet/pointnet
# Out:
# /content/CS479/CS479-Assignment-PointNet/pointnet

# %%
ls
# Out:
# checkpoints/  dataloaders/  train_ae.py   train_seg.py  visualization.ipynb
# data/         model.py      train_cls.py  utils/

# %%
# !gdown --folder https://drive.google.com/drive/folders/1Ly2DbsBMBXp75CGCA4vnJ3uoyDxOJz84 -O ./data/
# Out:
# Retrieving folder contents
# Processing file 1Xe_MqykNlTOTMVMp2MQJeM6i8cjw2irn hdf5_data.zip
# Processing file 1ocSySbS_-3CAhePrRk4kJRCRhEvLZMvz modelnet40_ply_hdf5_2048.zip
# Retrieving folder contents completed
# Building directory structure
# Building directory structure completed
# Downloading...
# From (original): https://drive.google.com/uc?id=1Xe_MqykNlTOTMVMp2MQJeM6i8cjw2irn
# From (redirected): https://drive.google.com/uc?id=1Xe_MqykNlTOTMVMp2MQJeM6i8cjw2irn&confirm=t&uuid=e75488fd-b570-4e1b-883f-e5e8b49ecf16
# To: /content/CS479/CS479-Assignment-PointNet/pointnet/data/cs479/hdf5_data.zip
# 100% 363M/363M [00:02<00:00, 163MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1ocSySbS_-3CAhePrRk4kJRCRhEvLZMvz
# From (redirected): https://drive.google.com/uc?id=1ocSySbS_-3CAhePrRk4kJRCRhEvLZMvz&confirm=t&uuid=d02153d7-81b4-44bd-b2ab-e9b1d6745973
# To: /content/CS479/CS479-Assignment-PointNet/pointnet/data/cs479/modelnet40_ply_hdf5_2048.zip
# ...

# %%
# !find ./data -type f -name "*.zip" -exec unzip -oq {} -d ./data/ \;

# %%
ls ./data
# Out:
# cs479/  hdf5_data/  __MACOSX/  modelnet40_ply_hdf5_2048/

# %%
mv ./data/hdf5_data ./data/shapenet_part_seg_hdf5_data

# %%
# !python train_cls.py
# Out:
# 1/100 epoch | loss: 1.8948 | accuracy: 43.8%: 100% 76/76 [00:09<00:00,  8.32it/s]
# train loss: 2.5426 train acc: 33.3% | val loss: 2.3940 val acc: 37.4%
# saving checkpoint to checkpoints/classification/10-08_11-37-15/Classification_ckpt_epoch0_metric37.44.ckpt
# 2/100 epoch | loss: 1.4392 | accuracy: 57.0%: 100% 76/76 [00:07<00:00, 10.18it/s]
# train loss: 1.5800 train acc: 54.6% | val loss: 1.9094 val acc: 47.4%
# saving checkpoint to checkpoints/classification/10-08_11-37-15/Classification_ckpt_epoch1_metric47.37.ckpt
# 3/100 epoch | loss: 1.1504 | accuracy: 74.2%: 100% 76/76 [00:07<00:00, 10.22it/s]
# train loss: 1.2301 train acc: 64.9% | val loss: 2.1622 val acc: 48.4%
# saving checkpoint to checkpoints/classification/10-08_11-37-15/Classification_ckpt_epoch2_metric48.38.ckpt
# 4/100 epoch | loss: 1.1344 | accuracy: 72.7%: 100% 76/76 [00:07<00:00, 10.20it/s]
# train loss: 1.0801 train acc: 70.6% | val loss: 1.9772 val acc: 55.1%
# ...

# %%
# !python train_seg.py
# Out:
# 1/100 epoch | loss: 1.1648 | accuracy: 66.3%: 100% 94/94 [00:17<00:00,  5.45it/s]
# train loss: 1.8515 | train acc: 48.6% | val loss: 1.4742 | val acc: 58.8% | val mIoU: 48.1%
# saving checkpoint to checkpoints/segmentation/10-08_11-51-32/Segmentation_ckpt_epoch0_metric48.13.ckpt
# 2/100 epoch | loss: 0.8090 | accuracy: 78.2%: 100% 94/94 [00:16<00:00,  5.58it/s]
# train loss: 0.8707 | train acc: 75.7% | val loss: 0.7722 | val acc: 78.8% | val mIoU: 63.3%
# saving checkpoint to checkpoints/segmentation/10-08_11-51-32/Segmentation_ckpt_epoch1_metric63.29.ckpt
# 3/100 epoch | loss: 0.7062 | accuracy: 79.9%: 100% 94/94 [00:16<00:00,  5.62it/s]
# train loss: 0.6594 | train acc: 81.4% | val loss: 0.6347 | val acc: 81.5% | val mIoU: 66.1%
# saving checkpoint to checkpoints/segmentation/10-08_11-51-32/Segmentation_ckpt_epoch2_metric66.11.ckpt
# 4/100 epoch | loss: 0.5442 | accuracy: 83.9%: 100% 94/94 [00:16<00:00,  5.62it/s]
# ...
